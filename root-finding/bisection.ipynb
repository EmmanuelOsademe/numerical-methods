# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Find the root of the equation y = x**3 + 4*x**2 - 10 using the bisection method

# Step 1: Generate a plot of the function to visualize what it looks like and inform on the possible initial guesses
x_vals = np.linspace(-10, 10, 50)
y_vals = [(x**3 + 4 * x**2 - 10) for x in x_vals]

plt.plot(x_vals, y_vals)
plt.show()
plt.clf()

# Step 2: Select appropriate a and b based on the observed plot
a = float(input("Enter the first guess: "))
b = float(input("Enter the second guess: "))

# Step 3: Check that neither a nor b is the root. Also check that the f(a) and f(b) are on either sides of the y-origin
fa = a**3 + 4 * a**2 - 10
fb = b**3 + 4 * b**2 - 10

while (fa * fb) > 0:
    print("Initial guesses must be on either side of the root. Make new guesses")
    a = float(input("Enter the first guess: "))
    b = float(input("Enter the second guess: "))
    fa = a**3 + 4 * a**2 - 10
    fb = b**3 + 4 * b**2 - 10
if fa == 0:
    print(f"The root of the equation is {a}")
    # return a;
if fb == 0:
    print(f"The root of the equation is {b}")
    # return b;

# Step 4: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-4
iters = 0
res = a
f_res = fa

while abs(f_res) > tol:
    res = a + 0.5 * (b - a)
    f_res = res**3 + 4 * res**2 - 10
    if f_res == 0:
        print(f"The root of the equation is {mid}")
    else:
        if (f_res*fa) > 0:
            a = res;
            fa = f_res
        else:
            b = res;
            fb = f_res
    iters += 1
    

print(res, iters)
# Out:
# Enter the first guess:  1
# Enter the second guess:  2
# 1.365234375 9

# %%
# Find the root of the equation y = (x+2)(x+1)x(x-1)**3(x-2) using the bisection method

# Step 1: Generate a plot of the function to visualize what it looks like and inform on the possible initial guesses
x_vals = np.linspace(-5, 5, 50)
y_vals = [((x + 2) * (x + 1) * x * (x - 1)**3 * (x-2)) for x in x_vals]

plt.plot(x_vals, y_vals)
plt.show()
plt.clf()

# Step 2: Select appropriate a and b based on the observed plot
a = float(input("Enter the first guess: "))
b = float(input("Enter the second guess: "))

# Step 3: Check that neither a nor b is the root. Also check that the f(a) and f(b) are on either sides of the y-origin
fa = (a + 2) * (a + 1) * a * (a - 1)**3 * (a - 2)
fb = (b + 2) * (b + 1) * b * (b - 1)**3 * (b - 2)

while (fa * fb) > 0:
    print("Initial guesses must be on either side of the root. Make new guesses")
    a = float(input("Enter the first guess: "))
    b = float(input("Enter the second guess: "))
    fa = (a + 2) * (a + 1) * a * (a - 1)**3 * (a - 2)
    fb = (b + 2) * (b + 1) * b * (b - 1)**3 * (b - 2)
if fa == 0:
    print(f"The root of the equation is {a}")
if fb == 0:
    print(f"The root of the equation is {b}")

# Step 4: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-4
iters = 0
res = a
f_res = fa

while abs(f_res) > tol:
    res = a + 0.5 * (b - a)
    f_res = (res + 2) * (res + 1) * res * (res - 1)**3 * (res - 2)
    if f_res == 0:
        print(f"The root of the equation is {mid}")
    else:
        if (f_res*fa) > 0:
            a = res;
            fa = f_res
        else:
            b = res;
            fb = f_res
    iters += 1
    

print(f"The root of the equation is {res}. Result attained after {iters} iterations")
# Out:
# Enter the first guess:  -1.5
# Enter the second guess:  1.75
# The root of the equation is 0.98828125. Result attained after 6 iterations

# %%
# Find the root of the equation y = (x+2)(x+1)^2 (x)(x-1)**3(x-2) using the bisection method

# Step 1: Generate a plot of the function to visualize what it looks like and inform on the possible initial guesses
x_vals = np.linspace(-5, 5, 50)
y_vals = [((x + 2) * (x + 1)**2 * x * (x - 1)**3 * (x-2)) for x in x_vals]

plt.plot(x_vals, y_vals)
plt.show()
plt.clf()

# Step 2: Select appropriate a and b based on the observed plot
a = float(input("Enter the first guess: "))
b = float(input("Enter the second guess: "))

# Step 3: Check that neither a nor b is the root. Also check that the f(a) and f(b) are on either sides of the y-origin
fa = (a + 2) * (a + 1)**2 * a * (a - 1)**3 * (a - 2)
fb = (b + 2) * (b + 1)**2 * b * (b - 1)**3 * (b - 2)

while (fa * fb) > 0:
    print("Initial guesses must be on either side of the root. Make new guesses")
    a = float(input("Enter the first guess: "))
    b = float(input("Enter the second guess: "))
    fa = (a + 2) * (a + 1)**2 * a * (a - 1)**3 * (a - 2)
    fb = (b + 2) * (b + 1)**2 * b * (b - 1)**3 * (b - 2)
if fa == 0:
    print(f"The root of the equation is {a}")
if fb == 0:
    print(f"The root of the equation is {b}")

# Step 4: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-4
iters = 0
res = a
f_res = fa

while abs(f_res) > tol:
    res = a + 0.5 * (b - a)
    f_res = (res + 2) * (res + 1)**2 * res * (res - 1)**3 * (res - 2)
    if f_res == 0:
        break
    else:
        if (f_res*fa) > 0:
            a = res;
            fa = f_res
        else:
            b = res;
            fb = f_res
    iters += 1
    

print(f"The root of the equation is {res}. Result attained after {iters} iterations")
# Out:
# Enter the first guess:  -3
# Enter the second guess:  -0.5
# The root of the equation is -1.999999761581421. Result attained after 21 iterations

# %%
# Use the Bisection method to find the approximation to sqrt of 3 within 0.0001 tolerance

# Step 1: Generate a plot of the function to visualize what it looks like and inform on the possible initial guesses
x_vals = np.linspace(-5, 5, 50)
y_vals = [(x**2 -3) for x in x_vals]

plt.plot(x_vals, y_vals)
plt.show()
plt.clf()

# Step 2: Select appropriate a and b based on the observed plot
a = float(input("Enter the first guess: "))
b = float(input("Enter the second guess: "))

# Step 3: Check that neither a nor b is the root. Also check that the f(a) and f(b) are on either sides of the y-origin
fa = a**2 - 3
fb = b**2 -3

while (fa * fb) > 0:
    print("Initial guesses must be on either side of the root. Make new guesses")
    a = float(input("Enter the first guess: "))
    b = float(input("Enter the second guess: "))
    fa = a**2 - 3
    fb = b**2 -3
if fa == 0:
    print(f"The root of the equation is {a}")
if fb == 0:
    print(f"The root of the equation is {b}")

# Step 4: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-4
iters = 0
res = a
f_res = fa

while abs(f_res) > tol:
    res = a + 0.5 * (b - a)
    f_res = res**2 -3
    if f_res == 0:
        break
    else:
        if (f_res*fa) > 0:
            a = res;
            fa = f_res
        else:
            b = res;
            fb = f_res
    iters += 1
    

print(f"The root of the equation is {res}. Result attained after {iters} iterations")
# Out:
# Enter the first guess:  1
# Enter the second guess:  2
# The root of the equation is 1.7320556640625. Result attained after 13 iterations
