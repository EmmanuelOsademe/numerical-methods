# %%
import numpy as np

# %%
# Find the root of the equation y = x**3 + 4*x**2 - 10 using the Newton_Raphson

# Step 1: Select appropriate a and b based on the observed plot
x = float(input("Enter initial guess: "))

# Step 2: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-10
iters = 0
max_iters =  30
error = 1000

while abs(error) > tol:
    fx = x**3 + 4 * x**2 - 10
    if fx == 0:
        print(f"The root of the equation is {x}")
        break
    
    fx_prime = 3 * x**2 + 8 * x
    x_new = x - fx/fx_prime
    error = x_new - x
    print((x, x_new, iters, error))
    iters += 1
    x = x_new
    if iters == max_iters:
        break
    
if iters == max_iters:
    print(f"Result not found after {iters} iterations");
else:
    print(f"Root of the equation is {x}\nSolution found after {iters} iterations")
# Out:
# Enter initial guess:  1
# (1.0, 1.4545454545454546, 0, 0.4545454545454546)
# (1.4545454545454546, 1.3689004010695187, 1, -0.08564505347593587)
# (1.3689004010695187, 1.365236600202116, 2, -0.003663800867402811)
# (1.365236600202116, 1.3652300134353668, 3, -6.586766749139272e-06)
# (1.3652300134353668, 1.3652300134140969, 4, -2.1269874750373674e-11)
# Root of the equation is 1.3652300134140969
# Solution found after 5 iterations

# %%
# Find the root of the equation y = x - 3**(-x) using the Newton_Raphson

# Step 1: Select appropriate a and b based on the observed plot
x = float(input("Enter initial guess: "))

# Step 2: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-10
iters = 0
max_iters =  30
error = 1000

while abs(error) > tol:
    fx = x - 3 ** (-1 * x)
    if fx == 0:
        print(f"The root of the equation is {x}")
        break
    
    fx_prime = 1 + np.log(3) * 3 **(-1 * x)
    x_new = x - fx/fx_prime
    error = x_new - x
    print((x, x_new, iters, error))
    iters += 1
    x = x_new
    if iters == max_iters:
        break
    
if iters == max_iters:
    print(f"Result not found after {iters} iterations");
else:
    print(f"Root of the equation is {x}\nSolution found after {iters} iterations")
# Out:
# Enter initial guess:  0.5
# (0.5, 0.5473297569017181, 0, 0.047329756901718145)
# (0.5473297569017181, 0.547808574321128, 1, 0.00047881741940980493)
# (0.547808574321128, 0.5478086216540969, 2, 4.7332968988733626e-08)
# (0.5478086216540969, 0.5478086216540974, 3, 4.440892098500626e-16)
# Root of the equation is 0.5478086216540974
# Solution found after 4 iterations

# %%
# Find the root of the equation y = 1/2 + x**2/4 - xsinx - cos(2x)/2 using the Newton_Raphson

# Step 1: Select appropriate a and b based on the observed plot
x = float(input("Enter initial guess: "))

# Step 2: Now that appropriate guesses have been made, define the tolerance and start the iteration
tol = 10**-5
iters = 0
max_iters =  100
error = 1000

while abs(error) > tol:
    fx = 0.5 + 0.25 * x**2 - x * np.sin(x) - 0.5 * np.cos(2 * x) 
    if fx == 0:
        print(f"The root of the equation is {x}")
        break
    
    fx_prime = 0.5 * x - np.sin(x) - x * np.cos(x) + np.sin(2*x)
    x_new = x - fx/fx_prime
    error = x_new - x
    print((x, x_new, iters, error))
    iters += 1
    x = x_new
    if iters == max_iters:
        break
    
if iters == max_iters:
    print(f"Result not found after {iters} iterations");
else:
    print(f"Root of the equation is {x}\nSolution found after {iters} iterations")
# Out:
# Enter initial guess:  15
# (15.0, 12.281186836072086, 0, -2.718813163927914)
# (12.281186836072086, 19.267466189418343, 1, 6.986279353346257)
# (19.267466189418343, 30.413891618672892, 2, 11.146425429254549)
# (30.413891618672892, 238.36914885384488, 3, 207.95525723517198)
# (238.36914885384488, 379.3049793165158, 4, 140.93583046267094)
# (379.3049793165158, 299.0209112187448, 5, -80.28406809777101)
# (299.0209112187448, 243.12029463581834, 6, -55.90061658292646)
# (243.12029463581834, 170.7081660939706, 7, -72.41212854184775)
# (170.7081660939706, -3074.6064981324503, 8, -3245.314664226421)
# (-3074.6064981324503, -2328.4387740184397, 9, 746.1677241140105)
# (-2328.4387740184397, -1902.8959697093044, 10, 425.54280430913536)
# (-1902.8959697093044, -6064.980995081554, 11, -4162.08502537225)
# (-6064.980995081554, -3681.557726449671, 12, 2383.4232686318833)
# (-3681.557726449671, -5845.891822483993, 13, -2164.3340960343216)
# (-5845.891822483993, -4737.623074923655, 14, 1108.268747560338)
# (-4737.623074923655, -7130.897287827067, 15, -2393.2742129034123)
# (-7130.897287827067, -11965.505470369097, 16, -4834.60818254203)
# (-11965.505470369097, -9434.029723754713, 17, 2531.4757466143838)
# (-9434.029723754713, -7845.94227682979, 18, 1588.087446924923)
# (-7845.94227682979, -4978.877818617486, 19, 2867.064458212304)
# (-4978.877818617486, -4060.0026350767234, 20, 918.8751835407625)
# (-4060.0026350767234, 61685.76361949571, 21, 65745.76625457243)
# (61685.76361949571, 50089.62164492705, 22, -11596.141974568658)
# (50089.62164492705, 75251.9595413647, 23, 25162.337896437653)
# (75251.9595413647, 47549.00265591004, 24, -27702.956885454667)
# (47549.00265591004, 36141.75277983812, 25, -11407.249876071917)
# (36141.75277983812, 98822.6062092555, 26, 62680.85342941737)
# (98822.6062092555, 185432.30519455485, 27, 86609.69898529936)
# (185432.30519455485, 154105.76573118, 28, -31326.53946337485)
# (154105.76573118, 108372.67620720429, 29, -45733.08952397571)
# (108372.67620720429, 167721.80307882564, 30, 59349.12687162135)
# (167721.80307882564, 79393.56576067978, 31, -88328.23731814587)
# (79393.56576067978, 168711.31141116572, 32, 89317.74565048594)
# (168711.31141116572, 71075.05948496057, 33, -97636.25192620515)
# (71075.05948496057, 110990.81512187156, 34, 39915.755636910995)
# (110990.81512187156, 63349.465456362224, 35, -47641.34966550934)
# (63349.465456362224, 50488.618970126845, 36, -12860.84648623538)
# (50488.618970126845, 42054.26140531537, 37, -8434.357564811478)
# (42054.26140531537, 129716.04660615177, 38, 87661.7852008364)
# (129716.04660615177, 201607.20152099006, 39, 71891.15491483829)
# (201607.20152099006, 31372.138544854883, 40, -170235.06297613517)
# (31372.138544854883, 47671.45967976211, 41, 16299.32113490723)
# (47671.45967976211, 172299.95578350977, 42, 124628.49610374766)
# (172299.95578350977, 138359.89875667807, 43, -33940.057026831695)
# (138359.89875667807, 104651.8118442255, 44, -33708.08691245256)
# (104651.8118442255, 356892.12150701135, 45, 252240.30966278585)
# (356892.12150701135, 1157279.892227747, 46, 800387.7707207357)
# (1157279.892227747, -1718362.1581850844, 47, -2875642.0504128314)
# (-1718362.1581850844, 41137408.23537921, 48, 42855770.3935643)
# (41137408.23537921, 101972825.63030025, 49, 60835417.39492104)
# (101972825.63030025, 56730518.61879179, 50, -45242307.011508465)
# (56730518.61879179, 47096534.39829981, 51, -9633984.220491976)
# (47096534.39829981, 24121886.504748203, 52, -22974647.89355161)
# (24121886.504748203, 20065379.26319283, 53, -4056507.241555374)
# (20065379.26319283, 13613380.506316157, 54, -6451998.756876672)
# (13613380.506316157, -4079998.7860725205, 55, -17693379.292388678)
# (-4079998.7860725205, -6173145.80459857, 56, -2093147.0185260493)
# (-6173145.80459857, -4607936.452279582, 57, 1565209.3523189882)
# (-4607936.452279582, -12002077.206933897, 58, -7394140.754654315)
# (-12002077.206933897, -20330491.451011043, 59, -8328414.244077146)
# (-20330491.451011043, -64730.63725243881, 60, 20265760.813758604)
# (-64730.63725243881, 17707.25000806307, 61, 82437.88726050188)
# (17707.25000806307, -8428.770184756078, 62, -26136.02019281915)
# (-8428.770184756078, -7016.9159970683195, 63, 1411.854187687759)
# (-7016.9159970683195, -1731.5338496520208, 64, 5285.382147416299)
# (-1731.5338496520208, -1415.3002332417914, 65, 316.2336164102294)
# (-1415.3002332417914, -726.2114019115407, 66, 689.0888313302506)
# (-726.2114019115407, -594.0839692385637, 67, 132.12743267297708)
# (-594.0839692385637, -491.4259637909153, 68, 102.65800544764835)
# (-491.4259637909153, -36.220539543824145, 69, 455.2054242470912)
# (-36.220539543824145, -12.800940702975659, 70, 23.419598840848487)
# (-12.800940702975659, -19.32639368519826, 71, -6.5254529822226)
# (-19.32639368519826, -31.173745101974255, 72, -11.847351416775997)
# (-31.173745101974255, -47.98143163125815, 73, -16.80768652928389)
# (-47.98143163125815, -37.261953797535526, 74, 10.719477833722621)
# (-37.261953797535526, -60.73029229475052, 75, -23.468338497214994)
# (-60.73029229475052, -45.21260644461259, 76, 15.51768585013793)
# (-45.21260644461259, 20.018396090684675, 77, 65.23100253529726)
# (20.018396090684675, -21.75787320654007, 78, -41.776269297224744)
# (-21.75787320654007, -18.143348582638176, 79, 3.614524623901893)
# (-18.143348582638176, -36.77747681127392, 80, -18.634128228635745)
# (-36.77747681127392, -128.55705181572466, 81, -91.77957500445075)
# (-128.55705181572466, -106.76746642473434, 82, 21.789585390990325)
# (-106.76746642473434, -160.31454455342242, 83, -53.547078128688085)
# (-160.31454455342242, -133.486572089674, 84, 26.82797246374841)
# (-133.486572089674, -63.38072248290459, 85, 70.10584960676943)
# (-63.38072248290459, -107.51456717211005, 86, -44.13384468920546)
# (-107.51456717211005, -207.88883784096527, 87, -100.37427066885522)
# (-207.88883784096527, -353.2378528737139, 88, -145.34901503274864)
# (-353.2378528737139, -69.8098109992726, 89, 283.4280418744413)
# (-69.8098109992726, -133.68897784190503, 90, -63.87916684263243)
# (-133.68897784190503, -84.57363578476618, 91, 49.11534205713885)
# (-84.57363578476618, -70.26524553450373, 92, 14.308390250262448)
# (-70.26524553450373, 116.31685788974825, 93, 186.58210342425198)
# (116.31685788974825, 96.86540807527763, 94, -19.45144981447062)
# (96.86540807527763, 79.31858892288133, 95, -17.546819152396296)
# (79.31858892288133, 62.66464732831171, 96, -16.653941594569623)
# (62.66464732831171, 95.06719269791247, 97, 32.402545369600766)
# (95.06719269791247, 223.18873159292093, 98, 128.12153889500846)
# (223.18873159292093, 185.7160278377399, 99, -37.472703755181044)
# Result not found after 100 iterations
